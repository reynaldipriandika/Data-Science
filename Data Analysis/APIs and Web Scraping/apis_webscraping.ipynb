# %% [markdown]
# #### Working With APIs In Python
#
# An API is a collection of tools that allows different applications to interact.
#
# We make an API request to the the web server with the data we want. The server then replies and sends it to us.
#
# The most common is a GET reques, which we use to retrieve data.

# %%
import requests
# Make a GET request to get the latest position of the ISS from the OpenNotify API.
response = requests.get("http://api.open-notify.org/iss-now.json")

# %%
status_code = response.status_code # Get the status code of the response
# Out:
# 200

# %% [markdown]
# The request we just made returned a **status code** of 200. Web servers return status codes every time they receive an API request.
#
# Here are some codes that are relevant to GET requests:
#
# | code | description |
# | - | - |
# | 200 | Everything went okay, and the server returned a result (if any). |
# | 300 | The server is redirecting you to a different endpoint. |
# | 401 | The server thinks you're not authenticated. |
# | 400 | The server thinks you made a bad request |
# | 403 | The resource you're trying to access is forbidden |
# | 404 | The server didn't find the resource you tried to access. |

# %%
# Make a GET request
response = requests.get("http://api.open-notify.org/iss-pass")
status_code = response.status_code
# Out:
# 404

# %% [markdown]
#  `iss-pass` wasn't a valid endpoint, so the API's server sent us a `404` status code in response.

# %%
# Make a GET request
response = requests.get("http://api.open-notify.org/iss-pass.json")
status_code = response.status_code # Assign the status code of the response
# Out:
# 400

# %% [markdown]
# In the last example, we got a `400` status code, which indicates a bad request.

# %%
# Set up the parameters we want to pass to the API
# This is the latitude and longitude of San Francisco.
parameters = {"lat":37.78, "lon":-122.41}

# Make a get request with the parameter
response = requests.get("http://api.open-notify.org/iss-pass.json",
params=parameters)

# Print the content of the response (the data the server returned)
content = response.content
# print(response.content)

# This gets the same data as the command above
# response = requests.get("http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74")
# print(response.content)
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1632869274, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 572, \n      "risetime": 1632872484\n    }, \n    {\n      "duration": 642, \n      "risetime": 1632878301\n    }, \n    {\n      "duration": 621, \n      "risetime": 1632884115\n    }, \n    {\n      "duration": 544, \n      "risetime": 1632938546\n    }, \n    {\n      "duration": 652, \n      "risetime": 1632944276\n    }\n  ]\n}\n'
# ...

# %% [markdown]
# JSON is the main format for sending and receiving data through APIs.
#
# We can convert list and dictionaries to JSON, and vice versa in Python.

# %%
# Make a list of fast food chains.
best_food_chains = ["Taco Bell", "Shake Shack", "Chipotle"]
print(type(best_food_chains))

# Import the JSON library.
import json

# Use json.dumps to convert best_food_chains to a string.
best_food_chains_string = json.dumps(best_food_chains)
print(type(best_food_chains_string))

# Convert best_food_chains_string back to a list.
print(type(json.loads(best_food_chains_string)))

# Make a dictionary
fast_food_franchise = {"Subway":24722,"McDonalds": 14098,
"Starbucks": 18821, "Pizza Hut": 7600}

# We can also dump a dictionary to a string and load it
fast_food_franchise_string = json.dumps(fast_food_franchise)
print(type(fast_food_franchise_string))

# Convert fast_food_franchise_string to a Python object.
fast_food_franchise_2 = json.loads(fast_food_franchise_string)
print(type(fast_food_franchise_2))
# Out:
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'str'>
# <class 'dict'>

# %% [markdown]
# We can get the content of a response as a Python object by using the .json() method on the response.

# %%
# Make the same request 
parameters = {"lat":37.78, "lon":-122.41}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# Get the response data as a Python object. Verify that it's a dictionary.
json_data = response.json()
print(type(json_data)) 
print(json_data)
# Out:
# <class 'dict'>
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1633338062, 'latitude': 37.78, 'longitude': -122.41, 'passes': 5}, 'response': [{'duration': 485, 'risetime': 1633373302}, {'duration': 652, 'risetime': 1633378996}, {'duration': 577, 'risetime': 1633384868}, {'duration': 487, 'risetime': 1633390794}, {'duration': 555, 'risetime': 1633396645}]}

# %% [markdown]
# The server also sends metadata with information on how it generated and decode it. This information appears in the response `headers`.

# %%
# Headers is a dictionary
print(response.headers)
content_type = response.headers["content-type"]
print(content_type)
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Mon, 04 Oct 2021 09:01:02 GMT', 'Content-Type': 'application/json', 'Content-Length': '521', 'Connection': 'keep-alive', 'Via': '1.1 vegur'}
# application/json

# %% [markdown]
# OpenNotify has one more API endpoint, astros.json. It tells us how many people are currently in space.

# %%
# Call the API here
response = requests.get("http://api.open-notify.org/astros.json")
json_data = response.json()

# retrieve the number key from the response dictionary
in_space_count = json_data["number"]
print(in_space_count)
# Out:
# 7

# %% [markdown]
# #### Working with APIs: Takeaways
# #### Syntax
# - Acessing the content of the data the server returns: `response.content`
# - Importing the JSON library: `import json`
# - Getting the content of a response as a Python object: `response.json()`
# - Acessing the information on how the server generated the data, and how to decode the data: `response.headers`
#
# #### Consepts
# - An application program interface (API) is aset of methods and tools that allows different application to interact. Web servers host APIs.

# %% [markdown]
# #### WEB SCRAPPING WITH Python
# #### Rules of Scraping
# When we scrape websites, we have to make sure we are following some guidelines so that we are treating the websites and their owners with respect.
#
# Always check website's Terms and Conditions before scraping. Read the statement on the legal use of data.

# %%
# from preprocess import turtles
# print(turtles)
respect = "I will not spam websites"

# %% [markdown]
# #### Requests
# In order to get the HTML of the website, we need to make a request to get the content of the webpage.

# %%
import requests
 
webpage = requests.get('https://www.codecademy.com/articles/http-requests')
print(webpage.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <title>HTTP Requests | Codecademy</title>
#     <link rel="shortcut icon" type="image/x-icon" href="https://www.codecademy.com/favicon.ico" />
#     <link rel="canonical" href="https://www.codecademy.com/articles/http-requests" />
#     <link rel="alternate" type="application/rss+xml" title="Codecademy Blog" href="/blog.rss" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <meta name="apple-itunes-app" content="app-id=1376029326">
#     <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="Fz/CixmH9E+2Xz4TTITFZhddq9UnzEWe2EyaUHpkDlqJq2iLQweWTTI3FmF0z1L0klWs6gc9fyZY3eXAoBAjvw==" />
#     <meta name="theme-color" content="#10162F"/>
#     <link rel="apple-touch-icon" href="/apple-touch-icon.png">
# ...

# %% [markdown]
# This code will print out the HTML of the page.

# %%
# import the requests library
import requests

# Make GET request to the URL 
webpage_response = requests.get("https://content.codecademy.com/courses/beautifulsoup/shellter.html")
# Store the content of the response
webpage = webpage_response.content
# Print to see the content of this HTML
print(webpage)
# Out:
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta charset="utf-8">\n    <title>Turtle Shellter</title>\n      <link href="https://fonts.googleapis.com/css?family=Poppins" rel="stylesheet">\n      <link rel=\'stylesheet\' type=\'text/css\' href=\'style.css\'>\n  <script async src=\'/cdn-cgi/bm/cv/669835187/api.js\'></script></head>\n\n  <body>\n      <div class="banner">\n        <h1>The Shellter</h1>\n        <span class="brag">The #1 Turtle Adoption website!</span>\n      </div>\n\n      <div class="about">\n        <p class="text">Click to learn more about each turtle</p>\n      </div>\n\n    <div class="grid">\n      <div class="box adopt">\n          <a href="aesop.html" class="more-info"><img src="aesop.png" class="headshot"></a>\n          <p>Aesop</p>\n      </div>\n\n      <div class="box adopt">\n          <a href="caesar.html" class="more-info"><img src="caesar.png" class="headshot"></a>\n          <p>Caesar</p>\n      </div>\n\n      <div class="box adopt">\n          <a href
# ...
